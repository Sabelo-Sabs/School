# %% [markdown]
# <a href="https://colab.research.google.com/github/Sabelo-Sabs/School/blob/main/Exercise%20Sympy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Sympy Exercises

# %%
import numpy as np
from sympy import *
x, y, z = symbols("x y z")
f,g = symbols("f g",cls = Function)

# %%
expr = Limit((1-cos(x))/(1 + x - exp(x)),x,0)

# %%
expr
# Out:
# Limit((1 - cos(x))/(x - exp(x) + 1), x, 0)

# %%
expr.doit()
# Out:
# -1

# %% [markdown]
# ---------

# %%
integ = Integral(x*ln(x),(x,1,2))
integ
# Out:
# Integral(x*log(x), (x, 1, 2))

# %%
integ.doit()
# Out:
# -3/4 + 2*log(2)

# %% [markdown]
# ---

# %%
func = idiff(x**5 + y**2 +cos(y)-3,y,x)

# %%
func
# Out:
# 5*x**4/(-2*y + sin(y))

# %% [markdown]
# ---

# %% [markdown]
# ---

# %%
plot_implicit(x**5 + y**2 +cos(y)-3)

# %% [markdown]
# ---

# %%
x=np.linspace(-1, 3, 100)
def f(x): return (7 - x**2)
plt.plot(x,f(x))
plt.axhline(color ='black')
plt.fill_between(x, f(x) ,where= [(x>=-1) and (x<=2) for x in x])

# %% [markdown]
# # Exercise 2
