# %% [markdown]
# <a href="https://colab.research.google.com/github/Sabelo-Sabs/School/blob/main/Programing_File_Manipulation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#1. Write a Python program to read an entire text file.
file_object = open("test.txt", "r")

# %%
file_object.read()
# Out:
# "This is my first file!\nMy name is Sibabalwe Sinyaniso\nAnd I'm a Data Scientist by profession.\n\nBy the way I'm a founder at _________ Company."

# %%
file_object.close()

# %% [markdown]
# ----

# %%
#2. Write a Python program to read first n lines of a file.
file_object = open("test.txt", "r") 
file_object.readline()
# Out:
# 'This is my first file!\n'

# %%
file_object.close()

# %% [markdown]
# ----

# %%
# 3. Write a Python program to append text to a file and display the text.
file_object = open("test.txt", "a") 
file_object.write("\n Goodbye")
file_object.close()

# %%
file_object = open("test.txt","r")
file_object.read()
# Out:
# "This is my first file!\nMy name is Sibabalwe Sinyaniso\nAnd I'm a Data Scientist by profession.\n\nBy the way I'm a founder at _________ Company.\n Goodbye"

# %%
file_object.close()

# %%
# Write a Python program to read a file line by line and store it into a list.
file_object = open("test.txt", "r") 
file_object.readlines()
# Out:
# ['This is my first file!\n',
#  'My name is Sibabalwe Sinyaniso\n',
#  "And I'm a Data Scientist by profession.\n",
#  '\n',
#  "By the way I'm a founder at _________ Company.\n",
#  ' Goodbye']

# %%
file_object.close()
