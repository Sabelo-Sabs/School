# %%
conda update sympy
# Out:
# Note: you may need to restart the kernel to use updated packages.
# # >>>>>>>>>>>>>>>>>>>>>> ERROR REPORT <<<<<<<<<<<<<<<<<<<<<<
#
#     Traceback (most recent call last):
#       File "C:\Users\sabelo sibabalwe\pythonI\lib\site-packages\conda\exceptions.py", line 1079, in __call__
#         return func(*args, **kwargs)
#       File "C:\Users\sabelo sibabalwe\pythonI\lib\site-packages\conda\cli\main.py", line 84, in _main
#         exit_code = do_call(args, p)
#       File "C:\Users\sabelo sibabalwe\pythonI\lib\site-packages\conda\cli\conda_argparse.py", line 82, in do_call
#         return getattr(module, func_name)(args, parser)
#       File "C:\Users\sabelo sibabalwe\pythonI\lib\site-packages\conda\cli\main_update.py", line 20, in execute
#         install(args, parser, 'update')
#       File "C:\Users\sabelo sibabalwe\pythonI\lib\site-packages\conda\cli\install.py", line 151, in install
#         if args.mkdir:
#     AttributeError: 'Namespace' object has no attribute 'mkdir'
#
# ...
