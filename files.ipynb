# %% [markdown]
# <a href="https://colab.research.google.com/github/Sabelo-Sabs/School/blob/main/files.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#(a) Write a Python program to read a file
file = open("test.txt", "r")
file.read()
file.close()

# %%
# (b)Count the number of lines in a text file.
file = open("test.txt", "r")
content = file.read()
lines = content.split("\n")
len(lines)
file.close()

# %%
# Write a Python program to read a file line by line and store it into a list.
file = open("test.txt", "r")
file.readlines()
file.close()

# %%
# Write a Python program to read a file line by line store it into a variable
file = open("test.txt", "r")
var = file.readlines()
file.close()

# %%
# Write a Python program to append text to a file and display the text.
file = open("test.txt", "a")
file.write("\n Uyi'Ghost yang'thola ngishaywa uvalo")
file.close()

# %%
file = open("test.txt", "r")
file.read()
file.close()

# %%
# Write a Python program to assess if a file is closed or not.
file = open("test.txt", "r")
file.closed
# Out:
# False

# %%
file.close()
file.closed
# Out:
# True
